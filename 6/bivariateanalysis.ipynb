# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
#importing tips dataset from seaborn library
tips = sns.load_dataset('tips')

# %%
titanic = pd.read_csv("train.csv")

# %%
flights = sns.load_dataset('flights')

# %%
iris = sns.load_dataset('iris')

# %% [markdown]
# ##### These datasets are stored as part of the Seaborn library and can be loaded using the seaborn.load_dataset()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### 1.Scatterplot (Numerical - Numerical)

# %%
sns.scatterplot(data = tips, x='total_bill', y='tip')
plt.title('Scatter plot of Total Bill vs Tip')
plt.show()

# %% [markdown]
# ##### this is linear , the amount of the bill mostly decide how much the tip is going to be

# %%
# can even add a regression line or color-code by a third variable-> hue 
sns.scatterplot(data=tips , x= 'total_bill' , y= 'tip' , hue = 'sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### multivariate analysis

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', style='smoker', markers={'Yes': '^', 'No': 'o'} ,hue = 'sex' ,size = 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 2.Bar Plot(Numerical - Categorical)

# %%
# using tiatanic dataset
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 92            93         0       1        Chaffee, Mr. Herbert Fuller    male
# 708          709         1       1               Cleaver, Miss. Alice  female
# 718          719         0       3                McEvoy, Mr. Michael    male
# 479          480         1       3           Hirvonen, Miss. Hildur E  female
# 536          537         0       1  Butt, Major. Archibald Willingham    male
#
#       Age  SibSp  Parch       Ticket      Fare Cabin Embarked
# 92   46.0      1      0  W.E.P. 5734   61.1750   E31        S
# 708  22.0      0      0       113781  151.5500   NaN        S
# 718   NaN      0      0        36568   15.5000   NaN        Q
# 479   2.0      0      1      3101298   12.2875   NaN        S
# 536  45.0      0      0       113050   26.5500   B38        S

# %%
# generally in barplot X->categorical data , y-> numerical data
sns.barplot(data=titanic , x='Pclass' , y='Age' , hue='Sex' )
plt.show()

# %%
sns.barplot(data=titanic, x = 'Survived' , y ='Fare' ,hue = 'Sex')
plt.plot()
# Out:
# []

# %% [markdown]
# ##### can clearly see that the higher the fare was higher chance of survival

# %% [markdown]
# ### 3.Box Plot (Numerical - Categorical)

# %%
sns.boxplot(data = titanic , x= 'Sex' , y= 'Age', hue = 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ### 4.Distplot(Numerical - Categorical)

# %%
sns.distplot(titanic[titanic['Survived'] == 0]['Age'],hist = False )
sns.distplot(titanic[titanic['Survived'] == 1]['Age'],hist = False )
# Out:
# C:\Users\swaya\AppData\Local\Temp\ipykernel_22568\988310027.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived'] == 0]['Age'],hist = False )
# C:\Users\swaya\AppData\Local\Temp\ipykernel_22568\988310027.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ### 5.Heatmap (Categorical - Categorical)

# %%
pd.crosstab(titanic['Pclass'] , titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
# we can plot this data on a heat map by seaborn library
sns.heatmap(pd.crosstab(titanic['Pclass'] , titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Pclass')['Survived'].mean()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
(titanic.groupby('Pclass')['Survived'].mean()*100).plot(kind ='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
(titanic.groupby('Sex')['Survived'].mean()*100).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# ### 6.Clustermap (Categorical - Categorical)

# %%
sns.clustermap(pd.crosstab(titanic['Parch'],titanic['Survived']))

# %% [markdown]
# ### 7.Pairplot
#
# ##### It creates a grid of plots showing pairwise relationships between numeric columns in a dataset.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue = 'species')

# %% [markdown]
# ### 8.Lineplot(Numerical - Numerical)

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
new = flights.groupby('year')[['passengers']].sum().reset_index()
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(data = flights , x = 'year' , y= 'passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.heatmap(flights.pivot_table(values = 'passengers' , index = 'month' , columns = 'year'))
# Out:
# C:\Users\swaya\AppData\Local\Temp\ipykernel_22568\2636690497.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values = 'passengers' , index = 'month' , columns = 'year'))
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(values = 'passengers' , index = 'month' , columns = 'year'))
# Out:
# C:\Users\swaya\AppData\Local\Temp\ipykernel_22568\3931183410.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values = 'passengers' , index = 'month' , columns = 'year'))
